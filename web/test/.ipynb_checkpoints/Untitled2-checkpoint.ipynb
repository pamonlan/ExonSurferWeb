# %%
# Plot the results
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")
sns.set_context("paper")

# %%
res = pd.read_csv("../test_speed.csv")
res.columns
# Out:
# Index(['gene', 'nro_primers', 'nro_design', 'time'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(x="time", y="nro_design", hue="gene", data=res, ax=ax)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Number of primers")
ax.set_title("Time to design primers")
plt.show()
